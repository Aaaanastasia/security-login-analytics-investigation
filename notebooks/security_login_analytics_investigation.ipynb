# %% [markdown]
# # Security Login Analytics Investigation
#
# This notebook runs the cleaned analysis script for the Senior Data Analyst assignment. The original Colab export is preserved as `original_colab_export.py`; the runnable version is `security_login_analytics_investigation.py`.

# %% [markdown]
# ## Data setup
#
# Before running the notebook, place the provided workbook at:
#
# `data/logins_db_for_assignment.xlsx`
#
# The raw workbook is not committed by default because this repository is intended to be public.

# %%
# %run security_login_analytics_investigation.py
